# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
    
from wrangle_grades import wrangle_grades

# %%
df = sns.load_dataset("iris")
sns.pairplot(df, hue="species")

# %%
# .corr will return correlation coefficients for each pair of continuous variables
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df.corr(), cmap='Blues')

# %%
df = wrangle_grades()
df = df.set_index("student_id")
df.head()
# Out:
#             exam1  exam2  exam3  final_grade
# student_id
# 1             100     90     95           96
# 2              98     93     96           95
# 3              85     83     87           87
# 4              83     80     86           85
# 5              93     90     96           97

# %% [markdown]
# # Business Question
# - Is one exam a better predictor of the final grade?
# - Which exam can we use to predict the final grade?

# %% [markdown]
# ## My Hypotheses:
# - Exam1 correlates with the final grade
# - Exam2 correlates w/ the final grade
# - Exam3 correlates w/ the final grade
# - The values for Exam1, Exam2, and Exam3 probably correlate with eachother
# - My own hypothesis is that exam3 has the strongest correlation with final_grade

# %%
# Super quick histogram of all the values
# There are cleaner ways to do this, but this provides the overview super quick
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1da22358>,
# ...
#       dtype=object)

# %%
sns.distplot(df.exam1)

# %%
sns.distplot(df.exam2)

# %%
sns.distplot(df.exam3)

# %%
sns.distplot(df.final_grade)

# %%
# Quick way to get the correlation coefficients
df.corr()
# Out:
#                 exam1     exam2     exam3  final_grade
# exam1        1.000000  0.933423  0.951743     0.983944
# exam2        0.933423  1.000000  0.938773     0.926679
# exam3        0.951743  0.938773  1.000000     0.959412
# final_grade  0.983944  0.926679  0.959412     1.000000

# %% [markdown]
# ## Findings so far (as a habit, write down what you learn when you learn it)
# - Exam1 has the highest correlation coefficient with final_grade
# - Exam1, Exam2, and Exam3 are all pretty tightly correlated with eachother

# %%
# plot out the correlations w/ a heatmap to get visual insight
plt.title("Heatmap of exams and final grade")
sns.heatmap(df.corr(), cmap='Blues', annot=True)
plt.show()

# %%
# Plot out all the pairs in this dataframe
sns.pairplot(df, kind="reg")
plt.show()

# %%
sns.lmplot("exam1", "final_grade", df)

# %%
sns.lmplot("exam2", "final_grade", df)
